# %%
from bs4 import BeautifulSoup as BS
import unittest
import random
from time import sleep
import pdb
import pandas as pd
import csv
import requests
from tqdm import tqdm
from pandas.io.sql import SQLTable
#import webscrape_pd_scrape_patheos as pscrape
import sys
#from passlib.hash import pbkdf2_sha256
try:
    from configparser import ConfigParser
    from configparser import SafeConfigParser
except ImportError:
    from ConfigParser import ConfigParser  # ver. < 3.0
    from ConfigParser import SafeConfigParser
    
HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/73.0.3683.114 Safari/537.36'),
                          'referer': 'https://www.patheos.com/blogs/'}

# %%
def update_system_status_values(file, section, option, value):
    config = ConfigParser()
    config.read(file)
    cfgfile = open(file, 'w')
    if config.has_section(section) == True:
        config.set(section, option, value)
    else:
        config.add_section(section)
        config.set(section, option, value)
    config.write(cfgfile)
    cfgfile.close()

# %%
def exists_config_file(file, section, option):
    config = ConfigParser()
    config.read(file)
    if config.has_option(section, option) == True:
        page_number = int(config.get(section, option))
    else:
        page_number = 1
    return page_number

# %%
url = 'http://www.patheos.com/blogs'
response = requests.get(url)
soup = BS(response.content, 'html.parser')

blog_list = []

for blog in soup.find_all('div', attrs={"class":"related-content clearfix related-content-sm decorated channel-list"}):
    blog_url1 = blog.find('a')
    blog_url2 = blog_url1['href']
    blog_list.append(blog_url2) 

blog_lists = []
    
for i in blog_list:
    split_url = i.rsplit("/")
    blog_name = split_url[3]
    blog_lists.append(blog_name)
    
blog_dict = {i:[] for i in blog_lists}

blog_cat_prefix = "https://www.patheos.com/"

i = 0    
for blog_urls in tqdm(blog_dict, desc='Fetch blog urls for each category'):
    if blog_urls:
        query_url = blog_cat_prefix + blog_urls
        sleep(random.uniform(1, 3))
        subsub_blog = requests.get(query_url)
        soup2 = BS(subsub_blog.content, 'html.parser')
        for blog in soup2.find_all('div', attrs={"class":"author-info"}):
            for blog_url0 in blog.find_all('div', attrs={"class":"title"}):
                blog_url1 = blog_url0.find('a')
                blog_url2 = blog_url1['href']
                blog_dict[blog_urls].append(blog_url2)
        i = i + 1
    else:
        continue
# Out:
# Fetch blog urls for each category: 100%|███████████████████████████████████████████████| 20/20 [00:42<00:00,  2.04s/it]

# %%
def test_404(blog, page_number, increment, name):
    pn = 0
    return_str = page_number
    continue_on = True
    if page_number < 1:
        pn = increment
        return_str = 0
    else:
        pn = page_number + increment    
    blog_test = requests.get(blog, timeout=5)
    blog_url = blog_test.url
    while continue_on == True:
        blog_page_url = blog_url + "page/" + str(pn)
        if pn < 20000:
            try:
                url_test = requests.get(blog_page_url, timeout=5) #, allow_redirects=True)
                sleep(random.uniform(1, 3))
                if url_test.status_code != 404:
                    sys.stdout.write('\r' + blog + " | page(" + str(pn) + ")") # | category total: (" + str(t) + ")")
                    return_str = pn
                    pn = pn + increment
                else:
                    continue_on = False                
            except:
                return_str = -1
                continue_on = False
        else:
            return_str = -2
            continue_on = False
    if increment == 1:
        sys.stdout.write('\r' + blog + " | page(" + str(return_str) + ")") # | category total: (" + str(t) + ")")        
    return return_str

# %% [raw]
# # TESTTESTTESTTESTTEST
#
# def test_404(blog, page_number, increment, name):
#     pn = 0
#     return_str = page_number
#     continue_on = True
#     if page_number < 1:
#         pn = increment
#         return_str = 0
#     else:
#         pn = page_number + increment
#     blog_test = requests.get(blog, timeout=5)
#     blog_url = blog_test.url
#     if increment == -100:
#         pn = page_number + 1
#         blog_page_url = blog_url + "page/" + str(pn)
#         url_test = requests.get(blog_page_url, timeout=5) #, allow_redirects=True)
#         sleep(random.uniform(1, 3))
#         if url_test.status_code != 404:
#             return_str = pn
#             sys.stdout.write('\r' + blog + " | page(" + str(pn) + ")") # | category total: (" + str(t) + ")")
#         else:
#             return_str = -90
#     else:
#         while continue_on == True:
#             blog_page_url = blog_url + "page/" + str(pn)
#
#             if pn < 20000:
#                 try:
#                     url_test = requests.get(blog_page_url, timeout=5) #, allow_redirects=True)
#                     sleep(random.uniform(1, 3))
#                     if url_test.status_code != 404:
#                         return_str = pn
#                         pn = pn + increment
#                         sys.stdout.write('\r' + blog + " | page(" + str(pn) + ")") # | category total: (" + str(t) + ")")
#                     else:
#                         continue_on = False
#                 except:
#                     return_str = -1
#                     continue_on = False
#             else:
#                 return_str = -2
#                 continue_on = False
#     if increment == 1:
#         sys.stdout.write('\r' + blog + " | page(" + str(return_str) + ")") # | category total: (" + str(t) + ")")
#     return return_str

# %%
def blog_find_pages(blogname_list, list_name):
    c = 0
    t = 1
    b = 1
    url_list = []
    continue_on = True
    for i in blogname_list:
        if i != "":
            try:
                continue_on = True
                page_prefix = "/page/"
                blog_name = i.rsplit("/")
                try:
                    p = int(exists_config_file('patheos_blogs_pages.ini', list_name, blog_name[4]))
                except:
                    continue
                if not p:
                    p = 0
                try:
                    p1 = test_404(i, p, 500, blog_name[4])
                except:
                    continue

                try:
                    sys.stdout.write('\r' + list_name.upper() + " | category number: " + str(b) + "/" + str(len(blogname_list)))
                except:
                    continue

                if ((p1 != -1) and (p1 != -2)):
                    p2 = test_404(i, p1, 100, blog_name[4])
                    p = p1
                    if p2 != -1:
                        p3 = test_404(i, p2, 50, blog_name[4])
                        p = p2
                        if p3 != -1:
                            p4 = test_404(i, p3, 25, blog_name[4])
                            p = p4

                if ((p != -1) and (p != -2)):
                    while continue_on == True:    
                        sys.stdout.write('\r' + list_name.upper() + " | category number: " + str(b) + "/" + str(len(blogname_list)))
                        p = test_404(i, p, 1, blog_name[4])
                        continue_on = False
                    t = t + p
                    b = b + 1
                    update_system_status_values('patheos_blogs_pages.ini', list_name, blog_name[4], str(p))
                else:
                    update_system_status_values('patheos_blogs_pages.ini', list_name, blog_name[4], str(p))
                    b = b + 1
                    sys.stdout.write('\r' + list_name.upper() + " | category number: " + str(b) + "/" + str(len(blogname_list)))
            except:
                p = -1
                update_system_status_values('patheos_blogs_pages.ini', list_name, blog_name[4], str(p))
                sys.stdout.write('\r' + list_name.upper() + " | category number: " + str(b) + "/" + str(len(blogname_list)))
        else:
            update_system_status_values('patheos_blogs_pages.ini', list_name, blog_name[4], str(p))
            sys.stdout.write('\r' + list_name.upper() + " | category number: " + str(b) + "/" + str(len(blogname_list)))

fail_list = []

# %%
def pass_dict_list(blog_dict, file):
    df_lists_results = pd.DataFrame()
    blog_posts = {i:[] for i in blog_dict}
    
    for i in blog_dict:
        result_list = fetch_page_posts(i, blog_dict[i], file)
        blog_posts[i].append(result_list)
        
    return blog_posts #dictionary    


def fetch_page_posts(list_name, pages_url_list, file):
    p = 1
    url_list = []
    continue_on = True
    page_prefix = "page/"
    
    #return_dict = {}
    
    for e in tqdm(pages_url_list, desc='Fetch Post URLs from Blogs (pass 1)'):
        if e:
            blog_name = e.rsplit("/")
            pages = exists_config_file(file, list_name, blog_name[4])
            
            blog_test = requests.get(e, timeout=5)
            blog_url = blog_test.url

            pull_page = 1
            while pull_page <= pages: 
                blog_page_url = blog_url + page_prefix + str(pull_page)
                print(blog_page_url)
                url_test = requests.get(blog_page_url)
                if url_test != "<Response [404]>":
                    soup2 = BS(url_test.content, 'html.parser')
                    for blog in soup2.find_all('h2', attrs={"class":"entry-title"}):
                        blog_url1 = blog.find('a')
                        blog_url2 = blog_url1['href']
                        print(blog_url2)
                        url_list.append(blog_url2)
                        #return_dict[list_name].append(blog_url2)
                    pull_page = pull_page + 1
                else:
                    continue
        #else:
            #break

    return url_list
    #return return_dict

pass_dict_list(blog_dict, 'patheos_blogs_pages.ini')
    
#posts_list = fetch_page_posts(url_list)
# Out:
# Fetch Post URLs from Blogs (pass 1):   0%|                                                       | 0/5 [00:00<?, ?it/s]
# https://www.patheos.com/blogs/americanbuddhist/page/1
# https://www.patheos.com/blogs/americanbuddhist/2019/05/im-still-here.html
# https://www.patheos.com/blogs/americanbuddhist/2019/03/spend-a-month-in-a-chinese-buddhist-monastery-this-summer-woodenfish-hbmlp-in-china.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/pause-breathe-smile-awakening-mindfulness-when-meditation-is-not-enough-a-review.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/buddhist-generosity-yokoji-zen-mountain-center-in-california-raises-over-5000-to-repair-storm-damage.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/further-abuse-accusations-against-sakyong-mipham-head-of-shambhala-buddhism.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/valentines-day-for-buddhists-a-warning.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/progressive-buddhism-an-australian-buddhist-nun-speaks-on-tibetan-buddhism-patriarch-and-india.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/petition-shambhala-buddhism-students-seek-to-split-from-authoritarian-structure.html
# https://www.patheos.com/blogs/americanbuddhist/2019/02/does-this-comment-spark-joy.html
# https://www.patheos.com/blogs/americanbuddhist/2019/01/anonymous-redditor-shares-troubling-experience-in-shambhala-buddhism.html
# https://www.patheos.com/blogs/americanbuddhist/page/2
# https://www.patheos.com/blogs/americanbuddhist/2019/01/a-wrap-up-of-2018-life-adventures-a-short-version.html
# https://www.patheos.com/blogs/americanbuddhist/2018/12/buddhists-need-to-make-more-room-for-understanding-anger.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/dr-martin-luther-king-jr-s-dream-and-buddhism.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/2014-fo-guang-buddhist-retreat.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/r-i-p-david-kalupahana-a-giant-in-the-field-of-buddhist-philosophy.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/the-effectiveness-of-meditation-a-meta-analysis.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/traveller-a-guest-post-by-naga-r-dhoopati.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/tibetan-prayer-flags-mark-the-worlds-scariest-bridge.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/nineteenth-joint-postgraduate-conference-on-religion-and-theology.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/16-guides-to-a-healthy-eco-consious-non-harming-2014-from-the-jain-elibrary-videos.html
# https://www.patheos.com/blogs/americanbuddhist/2014/01/buddhism-dominates-western-states-behind-christianity.html
# https://www.patheos.com/blogs/americanbuddhist/page/47
# https://www.patheos.com/blogs/americanbuddhist/2013/12/buddhanet-launches-buddhist-elibrary.html
# https://www.patheos.com/blogs/americanbuddhist/2013/12/2013-as-the-year-of-mindfulness-critics-and-defenders.html
# https://www.patheos.com/blogs/americanbuddhist/2013/12/japans-monks-without-borders-to-take-on-poverty.html
# https://www.patheos.com/blogs/americanbuddhist/2013/12/a-father-who-lost-his-son-at-sandy-hook-asks-thich-nhat-hanh-what-could-have-prevented-it.html
# https://www.patheos.com/blogs/americanbuddhist/2013/12/announcing-the-death-of-the-international-969-movement.html
# https://www.patheos.com/blogs/americanbuddhist/2013/12/rohatsu-bodhienlightenment-day.html
# https://www.patheos.com/blogs/americanbuddhist/2013/12/r-i-p-nelson-mandela-bodhisattva.html
# https://www.patheos.com/blogs/americanbuddhist/2013/11/a-very-buddhist-thanksgiving-with-video-from-mary-grace-orr-rev-thich-hang-dat-sensei-bob-oshita-and-ajahn-brahm.html
# https://www.patheos.com/blogs/americanbuddhist/2013/11/the-onion-satirizes-buddhism-extremist-cell-vows-to-unleash-tranquility-on-west.html
# https://www.patheos.com/blogs/americanbuddhist/2013/11/spanish-court-rules-for-tibetan-victims-of-chinese-genocide.html
# https://www.patheos.com/blogs/americanbuddhist/page/48
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d4e06e1d3623> in <module>()
#      48     #return return_dict
#      49
# ---> 50 pass_dict_list(blog_dict, 'patheos_blogs_pages.ini')
#      51
#      52 #posts_list = fetch_page_posts(url_list)
#
# <ipython-input-34-d4e06e1d3623> in pass_dict_list(blog_dict, file)
#       4
#       5     for i in blog_dict:
# ----> 6         result_list = fetch_page_posts(i, blog_dict[i], file)
#       7         blog_posts[i].append(result_list)
#       8
#
# <ipython-input-34-d4e06e1d3623> in fetch_page_posts(list_name, pages_url_list, file)
#      30                 blog_page_url = blog_url + page_prefix + str(pull_page)
#      31                 print(blog_page_url)
# ---> 32                 url_test = requests.get(blog_page_url)
#      33                 if url_test != "<Response [404]>":
#      34                     soup2 = BS(url_test.content, 'html.parser')
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\ben\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# c:\users\ben\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# c:\users\ben\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\users\ben\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\users\ben\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\users\ben\appdata\local\programs\python\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\users\ben\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\users\ben\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# For in file testing
keep = True
for i in blog_dict:
    #while keep == True:
        #keep = False
        #for b in blog_dict['progressive-christian-blogs']:
            #print(b)
        new_list = blog_find_pages(blog_dict[i], i)
        #new_list = blog_find_pages(blog_dict['progressive-christian-blogs'], 'progressive-christian-blogs')
# Out:
# CATHOLIC-BLOGS | category number: 1/79

# %%
for i in 
#    print(i)

# %%
# For in file testing
n = 0

for i in blog_dict:
    print(i, len(blog_dict[i]))
    n = n + len(blog_dict[i])

print("Total: " + str(n))

print(blog_dict['buddhist-blogs'])
# Out:
# buddhist-blogs 5
# catholic-blogs 79
# contemplative-blogs 9
# evangelical-blogs 79
# general-christian-blogs 16
# hindu-blogs 4
# jewish-blogs 6
# latter-day-saint-blogs 17
# muslim-blogs 34
# new-visions-blogs 34
# nonreligious-blogs 64
# pagan-blogs 53
# progressive-christian-blogs 97
# more-voices-blogs 3
# sixseeds-family-blogs 23
# politics-blue-blogs 3
# politics-red-blogs 10
# entertainment-blogs 12
# faith-and-work-blogs 16
# patheos-partner-blogs 2
# Total: 566
# ['https://www.patheos.com/blogs/americanbuddhist', 'https://www.patheos.com/blogs/bodhisattvaroad', 'https://www.patheos.com/blogs/monkeymind', 'https://www.patheos.com/blogs/notesfromthetemple', 'https://www.patheos.com/blogs/wildfoxzen']

# %%
# For in file testing
n = 0

for f in blog_dict['progressive-christian-blogs']:
    print(f)
    n = n + len(blog_dict['progressive-christian-blogs'])

print("Total: " + str(n))

# %%
response_list = []

teste = requests.get('https://www.patheos.com/blogs/jesuscrees')
print(teste.status_code)
print(teste.history)
for i in teste.history:
    response_list.append(i.status_code)
    rget = i.status_code

print(len(response_list))    
print(rget)
print(teste.url)

test1 = teste.url

test2 = requests.get(test1)
print(test2.status_code)

test = requests.get

# %%
test = requests.get('https://www.patheos.com/blogs/comingoutchristian')
print(test.status_code)
print(test.history)
for i in test.history:
    rget = i.status_code
print(rget)
print(test.url)

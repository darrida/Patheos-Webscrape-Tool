# %%
from interface_db import orm_peewee_classes as pw

# %%
blogs = pw.blog.select().order_by(pw.blog.last_date.desc())

# %%
type(blogs)
# Out:
# peewee.ModelSelect

# %%
print(blogs)
# Out:
# SELECT "t1"."id", "t1"."author", "t1"."name", "t1"."url", "t1"."category_id", "t1"."last_date", "t1"."last_user", "t1"."create_date", "t1"."create_user" FROM "blog" AS "t1"

# %%
for blog in blogs:
    print(blog.last_date, i.id, blog.name, blog.url, blog.author)
# Out:
# 2020-05-03 17:52:23.488460 575 Doc Hollywood https://www.patheos.com/blogs/dochollywood by Craig Detweiler
# 2020-05-03 17:49:45.573858 575 Cinemeditations https://www.patheos.com/blogs/cinemeditations by Andrew Johnson
# 2020-05-03 17:49:27.140781 575 Chrisicisms https://www.patheos.com/blogs/chrisicisms by Chris Williams
# 2020-05-03 17:46:22.410948 575 Backstage Pass https://www.patheos.com/blogs/backstagepass by Backstage Pass
# 2020-05-03 17:45:13.801451 575 {Take & Read} https://www.patheos.com/blogs/takeandread by {Take & Read}
# 2020-05-03 15:11:07.242432 575 Beyond All Telling https://www.patheos.com/blogs/beyondalltelling by Accidental Mystic
# 2020-05-03 15:10:08.869937 575 Betty Duffy https://www.patheos.com/blogs/duffy by Elizabeth Duffy
# 2020-05-03 15:09:25.556851 575 A Belief Observed https://www.patheos.com/blogs/abeliefobserved by Timothy Putnam
# ...
